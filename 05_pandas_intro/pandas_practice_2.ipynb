# %% [markdown]
# # Pandas Practice 2

# %% [markdown]
# ![IRIS, https://github.com/simonava5/fishers-iris-data](./images/iris.png)
#
# After the notebook with a lot of new input, let's start applying it totally by yourselves.
# For this purpose we will use one of the most standard real-life datasets: Its called Iris Dataset, and is all about the plant iris. Let's learn a little bit more about the dataset by looking at it.

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# By the end of this notebook, you will feel more comfortable with your newly acquired knowledge, as you will see that you can
#
# - load data from csv files into DataFrames
# - access data stored in DataFrames
# - use the general functions of a DataFrame to answer questions about the data
# - create insightful plots using the pandas function `.plot()`
# - explain what conclusions you draw from these visualizations.

# %%
# import pandas
import pandas as pd

# %%
# load the data
df = pd.read_csv('data/iris.csv')

# %% [markdown]
# Let us first have a look at the head of the table, maybe also on the last 10 rows...

# %%
print(df.shape)
df.info()
display(df.head())
display(df.tail(10))
# Out:
# (150, 5)
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#      sepal_length  sepal_width  petal_length  petal_width         species
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# How many irises are in the data set?

# %%
print("there are 150 entries (individual specimens) in the dataset")
# Out:
# there are 150 entries (individual specimens) in the dataset

# %% [markdown]
# How many different species are there?

# %%
df.species.nunique()
# Out:
# 3

# %% [markdown]
# Calculate the mean, median, mode for petal length

# %%
_pl = df.petal_length
_mode, *_ = _pl.mode()
print(f"""
mean:   {_pl.mean():0.1f} cm
median: {_pl.median():0.1f} cm
mode:   {_mode:0.1f} cm
""")

_pl.describe()
_pl.hist(bins=20)
# Out:
# mean:   3.8 cm
# median: 4.3 cm
# mode:   1.5 cm
# <Axes: >

# %% [markdown]
# What can you conclude about the distribution for petal length?

# %%
print("the distribution of petal length is bi-modal")
# Out:
# the distribution of petal length is bi-modal

# %% [markdown]
# What is the smallest and largest value for petal length?

# %%
print(f"""
smallest petal length: {_pl.min()} cm
largest petal length:  {_pl.max()} cm
""")
# Out:
# smallest petal length: 1.0 cm
# largest petal length:  6.9 cm

# %% [markdown]
# Calculate the variance and standard deviation for petal length

# %%
print(f"""
smallest petal length: {_pl.min()} cm
largest petal length:  {_pl.max()} cm
""")
# Out:
# smallest petal length: 1.0 cm
# largest petal length:  6.9 cm

# %% [markdown]
# Calculate the basic descriptive statistics for all columns of the iris data set with a single command.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# What is the overall average for sepal length?

# %%
print(f"average sepal length: {df.sepal_length.mean():0.1f} cm")
# Out:
# average sepal length: 5.8 cm

# %% [markdown]
# Use the DataFrame grouping function to determine the count by species.

# %%
df.groupby("species").count()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50

# %% [markdown]
# Use the DataFrame grouping function to determine the average length and width of sepals and pedals by species.

# %%
df.groupby("species").mean()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %% [markdown]
# Add the sum of the sepal width and length as a new column to your DataFrame.

# %%
df.eval("sepal_width_length = sepal_width + sepal_length")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      sepal_width_length
# 0                   8.6
# 1                   7.9
# 2                   7.9
# 3                   7.7
# 4                   8.6
# ..                  ...
# 145                 9.7
# 146                 8.8
# 147                 9.5
# 148                 9.6
# 149                 8.9
#
# [150 rows x 6 columns]

# %% [markdown]
# Visualize petal length with a histogram

# %%
_pl.hist()
# Out:
# <Axes: >

# %% [markdown]
# Describe the distribution

# %%
print("bimodal distribution centerd in ~1.5 and ~4.5")
# Out:
# bimodal distribution centerd in ~1.5 and ~4.5

# %% [markdown]
# Which is more informative: the summary statistics or visualizations?

# %%
print("viz is more informative. Both used together are a good tool ")
# Out:
# viz is more informative. Both used together are a good tool

# %% [markdown]
# Visualize petal length and width with a "scatter_matrix"

# %%
_ = pd.plotting.scatter_matrix(df)

# %% [markdown]
# Create a new column with a rough estimate of petal area by multiplying petal length and width together.

# %%
df.eval("petal_area = petal_length * petal_width")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      petal_area
# 0          0.28
# 1          0.28
# 2          0.26
# 3          0.30
# 4          0.28
# ..          ...
# 145       11.96
# 146        9.50
# 147       10.40
# 148       12.42
# 149        9.18
#
# [150 rows x 6 columns]

# %% [markdown]
# Create a new DataFrame with petal areas greater than $1cm^2$.

# %%
(df
 .eval("petal_area = petal_length * petal_width")
 .query("petal_area > 1")
 )
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species  \
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
#      petal_area
# 50         6.58
# 51         6.75
# 52         7.35
# 53         5.20
# 54         6.90
# ..          ...
# 145       11.96
# 146        9.50
# 147       10.40
# 148       12.42
# 149        9.18
#
# [100 rows x 6 columns]

# %% [markdown]
# Create 3 new DataFrames, one for each species. Use the entire dataset.

# %%
df_ver = df.query("species == 'Iris-versicolor'")
df_vir = df.query("species == 'Iris-virginica'")
df_set = df.query("species == 'Iris-setosa'")

print(df_ver.shape)
print(df_vir.shape)
print(df_set.shape)
# Out:
# (50, 5)
# (50, 5)
# (50, 5)
